# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt

sin = torch.sin
cos = torch.cos
exp = torch.exp
pi = torch.pi
torch.set_default_dtype(torch.float64)

epochs = 80000  # iterations
h = 100  # Test point grid density
N = 2000  # interior points
N1 = 100  # boundary points
N2 = 200  # data points

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    np.random.seed(seed)

setup_seed(123456)

def gen_testdata():
    data = np.load("/content/drive/MyDrive/2D_RS_Real_1_t.npz")
    t, x, y, usol = data["t"], data["x"], data["y"], data["u_sol"]
    xx, yy, tt = np.meshgrid(x, y, t)
    X = np.vstack((np.ravel(xx), np.ravel(yy), np.ravel(tt))).T
    z = usol.flatten()[:, None]
    return X, z

def l2_relative_error(z_true, z_pred):
    return np.linalg.norm(z_true - z_pred) / np.linalg.norm(z_true)

# Domain and Sampling
def interior(n=N):
    # sampling x∈[-3,3], y∈[-3,3], t∈[0,1]
    x = torch.rand(n, 1)*6 - 3  # [-3,3]
    y = torch.rand(n, 1)*6 - 3  # [-3,3]
    t = torch.rand(n, 1)        # [0,1]
    cond = torch.zeros_like(t)
    return x.requires_grad_(True), y.requires_grad_(True), t.requires_grad_(True), cond

def ini(n=N1):
    # IC t=0
    x = torch.rand(n, 1)*6 - 3
    y = torch.rand(n, 1)*6 - 3
    t = torch.zeros_like(x)
    cond = torch.where(x**2+y**2<0.25, a*torch.ones_like(x), torch.zeros_like(x))
    return x.requires_grad_(True), y.requires_grad_(True), t.requires_grad_(True), cond

def left(n=N1):
    # BC u(-3,y,t)=0
    t = torch.rand(n, 1)
    x = -3 * torch.ones_like(t)
    y = torch.rand(n, 1)*6 - 3
    cond = torch.zeros_like(t)
    return x.requires_grad_(True),y.requires_grad_(True), t.requires_grad_(True), cond

def right(n=N1):
    # BC u(3,y,t)=0
    t = torch.rand(n, 1)
    x = 3 * torch.ones_like(t)
    y = torch.rand(n, 1)*6 - 3
    cond = torch.zeros_like(t)
    return x.requires_grad_(True),y.requires_grad_(True), t.requires_grad_(True), cond

def up(n=N1):
    # BC u(x,3,t)=0
    t = torch.rand(n, 1)
    y = 3 * torch.ones_like(t)
    x = torch.rand(n, 1)*6 - 3
    cond = torch.zeros_like(t)
    return x.requires_grad_(True), y.requires_grad_(True),t.requires_grad_(True), cond

def down(n=N1):
    # BC u(x,-3,t)=0
    t = torch.rand(n, 1)
    y = -3 * torch.ones_like(t)
    x = torch.rand(n, 1)*6 - 3
    cond = torch.zeros_like(t)
    return x.requires_grad_(True),y.requires_grad_(True), t.requires_grad_(True), cond

def data_interior(n=N2):
    # data
    X, Y = gen_testdata()
    ids = np.random.randint(X.shape[0], size=n)
    xy_t = X[ids]
    u_real = Y[ids]
    xy_t = torch.from_numpy(xy_t)
    cond = torch.from_numpy(u_real)
    xy_t.requires_grad_(True)
    return xy_t, cond

# Neural Network
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(3, 64),  # input: x,y,t
            torch.nn.Tanh(),
            torch.nn.Linear(64, 64),
            torch.nn.Tanh(),
            torch.nn.Linear(64, 64),
            torch.nn.Tanh(),
            torch.nn.Linear(64, 1),
        )

    def forward(self, x):
        features = self.net(x)
        u_val = torch.abs(features)
        u_bce = torch.sigmoid(u_val)
        return u_val, u_bce

# Loss functions
loss = torch.nn.MSELoss()
bce_loss_fn = torch.nn.BCELoss()

def gradients(u, x, order=1):
    if order == 1:
        return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                 create_graph=True,
                                 only_inputs=True)[0]
    else:
        return gradients(gradients(u, x), x, order=order-1)

# Initialize unknown parameters

v = torch.nn.Parameter(torch.randn(1), requires_grad=True)
a = torch.nn.Parameter(torch.randn(1), requires_grad=True)

print('Initial v: ', v)
print('Initial a: ', a)

def l_interior(u):
    x, y, t, cond = interior()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    u_t = gradients(u_val, t, 1)
    u_x = gradients(u_val, x, 1)
    u_y = gradients(u_val, y, 1)
    u_xx = gradients(u_val, x, 2)
    u_yy = gradients(u_val, y, 2)
    residual = u_t - 6*u_val*(u_x**2+u_y**2)-3*(u_val**2)*(u_xx + u_yy) - v*u_val
    return loss(residual, cond)

def l_ini(u):
    # IC loss
    x, y, t, cond = ini()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    return loss(u_val, cond)

def l_left(u):
    # BC loss
    x, y, t, cond = left()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    return loss(u_val, cond)

def l_right(u):
    # BC loss
    x, y, t, cond = right()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    return loss(u_val, cond)

def l_up(u):
    # BC loss
    x, y, t, cond = up()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    return loss(u_val, cond)

def l_down(u):
    # BC loss
    x, y, t, cond = down()
    u_val, _ = u(torch.cat([x, y, t], dim=1))
    return loss(u_val, cond)

def l_data(u):
    xyt, cond = data_interior()
    _, u_bce = u(xyt)  # BCE
    cond_binary = cond.clamp(0, 1)
    return bce_loss_fn(u_bce, cond_binary)

# Training
u = MLP()
opt = torch.optim.RAdam(list(u.parameters()) + [v, a], lr=1e-3)
scheduler = StepLR(opt, step_size=1000, gamma=0.9)

# record training
L2_error = []
v_values = []
a_values = []
iterations = []

# obtain training data
xy_t, u_real = gen_testdata()
xy_t = torch.from_numpy(xy_t)

for i in range(epochs):
    opt.zero_grad()
    l_i = l_interior(u)
    l_d = l_data(u)
    l_initial = l_ini(u)
    l_u = l_up(u)
    l_dn = l_down(u)
    l_l = l_left(u)
    l_r = l_right(u)
    # loss function
    l = 1*l_i + 1*l_initial + l_dn + l_u + l_l + l_r + 5*l_data(u)
    l.backward()

    torch.nn.utils.clip_grad_norm_(u.parameters(), 0.1)
    torch.nn.utils.clip_grad_norm_([v, a], 0.1)  # Clip gradients for parameters too

    opt.step()
    scheduler.step()

    # Apply constraint to keep a positive
    #with torch.no_grad():
        #a.data = a.data.abs()

    # record
    v_values.append(v.item())
    a_values.append(a.item())
    iterations.append(i+1)

    if (i+1) % 1000 == 0 or i == 0:
        u_pred, _ = u(xy_t)
        error = l2_relative_error(u_real, u_pred.detach().numpy())
        L2_error.append(error)
        print(f"Epoch {i+1}, L2 Relative Error: {error}, v: {v.item():.4f}, a: {a.item():.4f}")
        print(f"  loss: {l.item():.6f}")
        print(f"  v grad: {v.grad.item():.6f}, a grad: {a.grad.item():.6f}")

print('Final v: ', v)
print('Final a: ', a)

# Plotting
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(iterations, v_values, 'b-', linewidth=2)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('v Values', fontsize=14)
plt.title('Changes of v W.R.T Iterations', fontsize=16)
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(iterations, a_values, 'r-', linewidth=2)
plt.xlabel('Iterations', fontsize=14)
plt.ylabel('a Values', fontsize=14)
plt.title('Changes of a W.R.T Iterations', fontsize=16)
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Initial v:  Parameter containing:
# tensor([1.8645], requires_grad=True)
# Initial a:  Parameter containing:
# tensor([0.4071], requires_grad=True)
# Epoch 1, L2 Relative Error: 0.9626376175820186, v: 1.8644, a: 0.4070
#   loss: 3.637314
#   v grad: 0.024927, a grad: 0.020576
# Epoch 1000, L2 Relative Error: 0.8303094371779092, v: 1.6097, a: 0.1596
#   loss: 3.415929
#   v grad: 0.002369, a grad: 0.003156
# Epoch 2000, L2 Relative Error: 0.6505197906812291, v: 1.8201, a: 0.2776
#   loss: 3.334436
#   v grad: -0.002097, a grad: -0.000008
# Epoch 3000, L2 Relative Error: 0.5930234199020158, v: 2.0810, a: 0.3422
#   loss: 3.325618
#   v grad: -0.002741, a grad: -0.001212
# Epoch 4000, L2 Relative Error: 0.5514833572777667, v: 2.2038, a: 0.3605
#   loss: 3.280977
#   v grad: 0.000563, a grad: -0.000210
# Epoch 5000, L2 Relative Error: 0.5373601343496939, v: 2.2888, a: 0.3691
#   loss: 3.326537
#   v grad: 0.002336, a grad: 0.001520
# Epoch 6000, L2 Relative Error: 0.5219788012414804, v: 2.3546, a: 0.3875
#   loss: 3.345424
#   v grad: -0.004114, a grad: 0.002044
# Epoch 7000, L2 Relative Error: 0.5101972599630787, v: 2.4378, a: 0.3921
#   loss: 3.223950
#   v grad: 0.002039, a grad: 0.002867
# Epoch 8000, L2 Relative Error: 0.512608196690468, v: 2.4898, a: 0.3973
#   loss: 3.265598
#   v grad: 0.000415, a grad: -0.000985
# Epoch 9000, L2 Relative Error: 0.5036532805064031, v: 2.5298, a: 0.3929
#   loss: 3.292562
#   v grad: -0.000118, a grad: -0.000575
# Epoch 10000, L2 Relative Error: 0.4944350412776111, v: 2.5790, a: 0.3955
#   loss: 3.179907
#   v grad: 0.000061, a grad: -0.003219
# Epoch 11000, L2 Relative Error: 0.4903986642113153, v: 2.6271, a: 0.3872
#   loss: 3.259214
#   v grad: -0.009663, a grad: -0.000737
# Epoch 12000, L2 Relative Error: 0.4977416148179812, v: 2.6679, a: 0.3936
#   loss: 3.306384
#   v grad: -0.003464, a grad: -0.000148
# Epoch 13000, L2 Relative Error: 0.5049712503062138, v: 2.7331, a: 0.3845
#   loss: 3.328836
#   v grad: -0.000839, a grad: 0.000968
# Epoch 14000, L2 Relative Error: 0.48453375725589737, v: 2.7623, a: 0.3796
#   loss: 3.231759
#   v grad: -0.002853, a grad: -0.001996
# Epoch 15000, L2 Relative Error: 0.48286095203560814, v: 2.8185, a: 0.3782
#   loss: 3.231428
#   v grad: 0.002855, a grad: 0.000821
# Epoch 16000, L2 Relative Error: 0.47805058642076076, v: 2.8522, a: 0.3744
#   loss: 3.188710
#   v grad: -0.000843, a grad: -0.000570
# Epoch 17000, L2 Relative Error: 0.4761807931551254, v: 2.8913, a: 0.3743
#   loss: 3.201248
#   v grad: -0.005408, a grad: 0.002112
# Epoch 18000, L2 Relative Error: 0.46305022537004575, v: 2.9243, a: 0.3765
#   loss: 3.207453
#   v grad: 0.002683, a grad: -0.002909
# Epoch 19000, L2 Relative Error: 0.46661518578832767, v: 2.9545, a: 0.3734
#   loss: 3.225101
#   v grad: 0.002615, a grad: 0.000000
# Epoch 20000, L2 Relative Error: 0.47281397362255945, v: 2.9775, a: 0.3728
#   loss: 3.197084
#   v grad: 0.004146, a grad: -0.001784
# Epoch 21000, L2 Relative Error: 0.4643617266069277, v: 2.9922, a: 0.3752
#   loss: 3.270443
#   v grad: 0.003386, a grad: -0.001982
# Epoch 22000, L2 Relative Error: 0.4623650024496045, v: 3.0133, a: 0.3790
#   loss: 3.280759
#   v grad: 0.000212, a grad: 0.004676
# Epoch 23000, L2 Relative Error: 0.462900249483072, v: 3.0242, a: 0.3768
#   loss: 3.257113
#   v grad: 0.000013, a grad: -0.001620
# Epoch 24000, L2 Relative Error: 0.4596942534972747, v: 3.0307, a: 0.3758
#   loss: 3.201573
#   v grad: -0.004147, a grad: 0.001813
# Epoch 25000, L2 Relative Error: 0.45993173922440644, v: 3.0437, a: 0.3741
#   loss: 3.249806
#   v grad: -0.000422, a grad: 0.002658
# Epoch 26000, L2 Relative Error: 0.4590080428307916, v: 3.0521, a: 0.3767
#   loss: 3.231470
#   v grad: -0.001663, a grad: 0.002251
# Epoch 27000, L2 Relative Error: 0.4564502799063577, v: 3.0560, a: 0.3776
#   loss: 3.269770
#   v grad: -0.002012, a grad: -0.001608
# Epoch 28000, L2 Relative Error: 0.4541853043244193, v: 3.0660, a: 0.3768
#   loss: 3.247807
#   v grad: -0.003650, a grad: -0.000626
# Epoch 29000, L2 Relative Error: 0.4531233363493281, v: 3.0783, a: 0.3756
#   loss: 3.253352
#   v grad: -0.002200, a grad: -0.001551
# Epoch 30000, L2 Relative Error: 0.45837993153238027, v: 3.0849, a: 0.3751
#   loss: 3.220997
#   v grad: 0.000168, a grad: 0.000520
# Epoch 31000, L2 Relative Error: 0.45121288280307126, v: 3.0882, a: 0.3768
#   loss: 3.165831
#   v grad: -0.002640, a grad: 0.000000
# Epoch 32000, L2 Relative Error: 0.4516433471729185, v: 3.0952, a: 0.3766
#   loss: 3.221924
#   v grad: -0.000801, a grad: -0.000395
# Epoch 33000, L2 Relative Error: 0.45299380523228494, v: 3.0985, a: 0.3764
#   loss: 3.329176
#   v grad: -0.003139, a grad: -0.004745
# Epoch 34000, L2 Relative Error: 0.45253793097050554, v: 3.1019, a: 0.3761
#   loss: 3.275988
#   v grad: -0.002440, a grad: 0.002162
# Epoch 35000, L2 Relative Error: 0.453418102835823, v: 3.1065, a: 0.3754
#   loss: 3.234702
#   v grad: 0.001948, a grad: -0.005821
# Epoch 36000, L2 Relative Error: 0.45470779117088983, v: 3.1109, a: 0.3769
#   loss: 3.301481
#   v grad: -0.002353, a grad: 0.000165
# Epoch 37000, L2 Relative Error: 0.45099135316826205, v: 3.1141, a: 0.3776
#   loss: 3.234743
#   v grad: -0.007080, a grad: -0.001485
# Epoch 38000, L2 Relative Error: 0.45202223516739715, v: 3.1170, a: 0.3771
#   loss: 3.226624
#   v grad: 0.007993, a grad: 0.001480
# Epoch 39000, L2 Relative Error: 0.4505553055858775, v: 3.1185, a: 0.3764
#   loss: 3.254150
#   v grad: -0.003925, a grad: 0.001218
# Epoch 40000, L2 Relative Error: 0.45267059489712524, v: 3.1213, a: 0.3758
#   loss: 3.319151
#   v grad: -0.000010, a grad: 0.002264
# Epoch 41000, L2 Relative Error: 0.4488873018823289, v: 3.1236, a: 0.3754
#   loss: 3.172797
#   v grad: 0.000821, a grad: 0.002091
# Epoch 42000, L2 Relative Error: 0.4514035007896856, v: 3.1263, a: 0.3747
#   loss: 3.190240
#   v grad: 0.003731, a grad: 0.000000
# Epoch 43000, L2 Relative Error: 0.4474538773993204, v: 3.1273, a: 0.3747
#   loss: 3.183065
#   v grad: -0.004004, a grad: -0.000291
# Epoch 44000, L2 Relative Error: 0.45005377310303624, v: 3.1282, a: 0.3754
#   loss: 3.235979
#   v grad: -0.002575, a grad: -0.003442
# Epoch 45000, L2 Relative Error: 0.4498845894623996, v: 3.1295, a: 0.3753
#   loss: 3.095387
#   v grad: 0.004566, a grad: -0.000052
# Epoch 46000, L2 Relative Error: 0.4491160583722407, v: 3.1311, a: 0.3756
#   loss: 3.192336
#   v grad: 0.001370, a grad: 0.002687
# Epoch 47000, L2 Relative Error: 0.44838090822524607, v: 3.1326, a: 0.3758
#   loss: 3.208238
#   v grad: 0.001739, a grad: -0.001699
# Epoch 48000, L2 Relative Error: 0.45013188882742633, v: 3.1341, a: 0.3755
#   loss: 3.233778
#   v grad: -0.003210, a grad: -0.003659
# Epoch 49000, L2 Relative Error: 0.44759679144898723, v: 3.1359, a: 0.3753
#   loss: 3.229535
#   v grad: -0.001997, a grad: -0.000541
# Epoch 50000, L2 Relative Error: 0.4483434337958324, v: 3.1367, a: 0.3752
#   loss: 3.125572
#   v grad: 0.002631, a grad: 0.001813
# Epoch 51000, L2 Relative Error: 0.44915486980378566, v: 3.1370, a: 0.3750
#   loss: 3.260587
#   v grad: 0.002872, a grad: -0.000839
# Epoch 52000, L2 Relative Error: 0.4494729715048608, v: 3.1376, a: 0.3751
#   loss: 3.233088
#   v grad: 0.000275, a grad: -0.000669
# Epoch 53000, L2 Relative Error: 0.448115674309835, v: 3.1383, a: 0.3751
#   loss: 3.229488
#   v grad: -0.001679, a grad: 0.002254
# Epoch 54000, L2 Relative Error: 0.44822424002797445, v: 3.1387, a: 0.3752
#   loss: 3.271384
#   v grad: -0.002235, a grad: -0.000104
# Epoch 55000, L2 Relative Error: 0.4491422437781227, v: 3.1395, a: 0.3752
#   loss: 3.182917
#   v grad: 0.000848, a grad: 0.000000
# Epoch 56000, L2 Relative Error: 0.4486302899626497, v: 3.1400, a: 0.3753
#   loss: 3.194342
#   v grad: -0.002092, a grad: 0.000606
# Epoch 57000, L2 Relative Error: 0.4485407953837708, v: 3.1406, a: 0.3754
#   loss: 3.142967
#   v grad: 0.003902, a grad: -0.001111
# Epoch 58000, L2 Relative Error: 0.44945815908947423, v: 3.1410, a: 0.3754
#   loss: 3.258492
#   v grad: 0.001417, a grad: 0.000000
# Epoch 59000, L2 Relative Error: 0.44901176235951584, v: 3.1415, a: 0.3753
#   loss: 3.262274
#   v grad: -0.001228, a grad: 0.000355
# Epoch 60000, L2 Relative Error: 0.44939156255776747, v: 3.1417, a: 0.3754
#   loss: 3.221640
#   v grad: -0.002354, a grad: -0.001202
# Epoch 61000, L2 Relative Error: 0.44892209188364435, v: 3.1420, a: 0.3754
#   loss: 3.200278
#   v grad: 0.003560, a grad: 0.001989
# Epoch 62000, L2 Relative Error: 0.449204323132951, v: 3.1422, a: 0.3754
#   loss: 3.185410
#   v grad: -0.004056, a grad: -0.000605
# Epoch 63000, L2 Relative Error: 0.4489149240656684, v: 3.1424, a: 0.3754
#   loss: 3.151203
#   v grad: -0.000819, a grad: 0.004148
# Epoch 64000, L2 Relative Error: 0.44859580768955476, v: 3.1426, a: 0.3753
#   loss: 3.124947
#   v grad: -0.000872, a grad: -0.001626
# Epoch 65000, L2 Relative Error: 0.4489412221987611, v: 3.1428, a: 0.3754
#   loss: 3.292143
#   v grad: 0.007384, a grad: 0.001339
# Epoch 66000, L2 Relative Error: 0.44899917570778825, v: 3.1429, a: 0.3754
#   loss: 3.210816
#   v grad: 0.000186, a grad: -0.000038
# Epoch 67000, L2 Relative Error: 0.4486449723958626, v: 3.1431, a: 0.3754
#   loss: 3.208554
#   v grad: -0.000891, a grad: 0.002184
# Epoch 68000, L2 Relative Error: 0.44835904783068553, v: 3.1433, a: 0.3754
#   loss: 3.285666
#   v grad: 0.005315, a grad: -0.000532
# Epoch 69000, L2 Relative Error: 0.44817094958011816, v: 3.1434, a: 0.3754
#   loss: 3.128345
#   v grad: 0.000353, a grad: -0.001418
# Epoch 70000, L2 Relative Error: 0.44813762079869346, v: 3.1435, a: 0.3754
#   loss: 3.274077
#   v grad: 0.000705, a grad: -0.000927
# Epoch 71000, L2 Relative Error: 0.44830895662117587, v: 3.1436, a: 0.3754
#   loss: 3.252287
#   v grad: 0.000742, a grad: 0.000000
# Epoch 72000, L2 Relative Error: 0.4480068520599841, v: 3.1437, a: 0.3754
#   loss: 3.247626
#   v grad: 0.002583, a grad: -0.000390
# Epoch 73000, L2 Relative Error: 0.44787484300715596, v: 3.1437, a: 0.3754
#   loss: 3.212816
#   v grad: 0.005382, a grad: 0.001832
# Epoch 74000, L2 Relative Error: 0.4479304963401514, v: 3.1438, a: 0.3755
#   loss: 3.239841
#   v grad: -0.001942, a grad: 0.000000
# Epoch 75000, L2 Relative Error: 0.4481264147962857, v: 3.1439, a: 0.3754
#   loss: 3.235778
#   v grad: -0.002125, a grad: 0.000418
# Epoch 76000, L2 Relative Error: 0.4482844209667755, v: 3.1440, a: 0.3754
#   loss: 3.306670
#   v grad: -0.002476, a grad: 0.001515
# Epoch 77000, L2 Relative Error: 0.44810229650713984, v: 3.1440, a: 0.3754
#   loss: 3.325337
#   v grad: 0.000577, a grad: 0.004634
# Epoch 78000, L2 Relative Error: 0.447931981466865, v: 3.1440, a: 0.3754
#   loss: 3.164402
#   v grad: -0.003035, a grad: 0.001345
# Epoch 79000, L2 Relative Error: 0.447904940056259, v: 3.1441, a: 0.3754
#   loss: 3.297741
#   v grad: -0.004046, a grad: 0.000000
# Epoch 80000, L2 Relative Error: 0.4479637228779056, v: 3.1441, a: 0.3754
#   loss: 3.172391
#   v grad: 0.003215, a grad: 0.000000
# Final v:  Parameter containing:
# tensor([3.1441], requires_grad=True)
# Final a:  Parameter containing:
# tensor([0.3754], requires_grad=True)
